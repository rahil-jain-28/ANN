# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
# %tensorflow_version 1.x
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return target_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
#     labels = tf.placeholder(tf.int32, [None, None], name='labels')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding))) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab), name="softmax_bias") # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        weights=softmax_w,
        biases=softmax_b,
        labels=labels,
        inputs=embed,
        num_sampled=n_sampled,
        num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-13-2aa168c49a56>:13: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 17.8827 0.0414 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 17.6869 0.0221 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 17.4637 0.0223 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 17.4449 0.0219 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 17.1977 0.0221 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 17.1098 0.0222 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 17.0323 0.0220 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 16.8881 0.0221 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 16.7213 0.0220 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 16.6048 0.0220 sec/batch
# Nearest to up: math, fats, substructure, system, newly, bogor, zulus, opec,
# Nearest to in: ugosz, overshadowing, alleles, diu, cartoonists, endings, artaphernes, hijaz,
# Nearest to state: saffron, olympiade, beag, kilocalories, retorted, baryonic, successor, architectural,
# Nearest to most: kochi, cielo, wrest, planning, minors, mergers, sued, hijjah,
# Nearest to may: partisanship, interchangeability, failure, hua, ngos, sutton, simplex, melton,
# Nearest to such: mexicans, wlad, latter, narthex, lancer, eileen, sonatas, amity,
# Nearest to have: uncommon, violinist, keypress, bitches, intersubjectivity, entropy, smote, octet,
# Nearest to by: krebs, agent, lenat, nem, inelegant, capitalist, deb, ebooks,
# Nearest to versions: fiennes, contacted, plenary, emmerdale, lithium, bios, acknowledges, bloodedness,
# Nearest to brother: toe, cartographer, snatched, deum, propanone, propounded, steinbeck, invented,
# Nearest to taking: lolf, peaceable, borwein, boty, tutankhamun, gripped, excitotoxins, miko,
# Nearest to notes: uncompleted, hyperactivity, kerman, reciprocals, ebitda, transcaucasian, chopin, puzzle,
# Nearest to shows: tryst, harpercollins, puzzling, assailed, skeptics, foundered, optic, representationalism,
# Nearest to behind: livermore, mocked, ekaggata, staroffice, upholds, musicianship, mitochondrion, indications,
# Nearest to proposed: maius, openstep, their, fiesole, intellects, jbls, bc, maclaurin,
# Nearest to arts: qualifying, spitz, easing, tsvetaeva, homophones, sagittarius, mesures, lillard,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 16.5838 0.0235 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 16.4332 0.0221 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 16.3311 0.0221 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 16.1653 0.0219 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 16.0895 0.0220 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 15.9878 0.0219 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 15.8683 0.0219 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 15.7560 0.0220 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 15.5797 0.0219 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 15.5258 0.0221 sec/batch
# Nearest to up: math, fats, substructure, system, zulus, newly, bogor, kos,
# Nearest to in: overshadowing, ugosz, alleles, endings, cartoonists, diu, hijaz, artaphernes,
# Nearest to state: beag, saffron, olympiade, kilocalories, retorted, architectural, baryonic, successor,
# Nearest to most: cielo, kochi, wrest, planning, minors, mergers, hijjah, ropes,
# Nearest to may: partisanship, failure, interchangeability, hua, ngos, sutton, shawn, simplex,
# Nearest to such: mexicans, latter, wlad, eileen, narthex, lancer, sonatas, salyut,
# Nearest to have: uncommon, violinist, keypress, bitches, entropy, externally, smote, intersubjectivity,
# Nearest to by: krebs, agent, lenat, nem, inelegant, ebooks, deb, hsv,
# Nearest to versions: contacted, fiennes, emmerdale, plenary, lithium, acknowledges, bios, bloodedness,
# Nearest to brother: toe, snatched, cartographer, propounded, deum, propanone, steinbeck, menendez,
# Nearest to taking: lolf, boty, borwein, peaceable, excitotoxins, miko, coulombs, tutankhamun,
# Nearest to notes: uncompleted, hyperactivity, kerman, puzzle, reciprocals, chopin, matriculated, musashi,
# Nearest to shows: harpercollins, optic, tryst, puzzling, raceway, representationalism, skeptics, assailed,
# Nearest to behind: ekaggata, mocked, livermore, staroffice, upholds, musicianship, indications, ajmer,
# Nearest to proposed: maius, openstep, their, fiesole, jbls, intellects, bc, yum,
# Nearest to arts: qualifying, spitz, easing, homophones, tsvetaeva, lillard, sagittarius, mesures,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 15.4311 0.0230 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 15.3861 0.0220 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 15.2957 0.0221 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 15.0860 0.0221 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 14.9934 0.0221 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 14.9099 0.0222 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 14.8437 0.0222 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 14.7369 0.0220 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 14.6605 0.0221 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 14.5627 0.0221 sec/batch
# Nearest to up: math, fats, substructure, kos, newly, bogor, zulus, system,
# Nearest to in: overshadowing, ugosz, endings, alleles, famicom, ongoing, cartoonists, oj,
# Nearest to state: beag, saffron, olympiade, retorted, kilocalories, successor, architectural, baryonic,
# Nearest to most: kochi, cielo, wrest, planning, mergers, hijjah, ropes, sector,
# Nearest to may: partisanship, failure, interchangeability, hua, shawn, sutton, ngos, simplex,
# Nearest to such: mexicans, wlad, latter, eileen, lancer, inexact, settle, narthex,
# Nearest to have: uncommon, violinist, keypress, bitches, entropy, externally, crm, fowl,
# Nearest to by: agent, krebs, lenat, nem, ebooks, inelegant, ampere, melba,
# Nearest to versions: contacted, fiennes, emmerdale, bios, plenary, lithium, acknowledges, bloodedness,
# Nearest to brother: toe, propounded, snatched, cartographer, steinbeck, propanone, deum, gables,
# Nearest to taking: lolf, boty, peaceable, borwein, coulombs, miko, excitotoxins, malignancy,
# Nearest to notes: uncompleted, hyperactivity, matriculated, musashi, chopin, kerman, reciprocals, performace,
# Nearest to shows: representationalism, optic, harpercollins, puzzling, raceway, pwn, plots, xzibit,
# Nearest to behind: ekaggata, staroffice, musicianship, mocked, upholds, ajmer, livermore, mitochondrion,
# Nearest to proposed: maius, jbls, their, openstep, fiesole, intellects, yum, bc,
# Nearest to arts: qualifying, spitz, easing, sagittarius, homophones, tsvetaeva, mesures, lillard,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 14.4326 0.0230 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 14.3845 0.0223 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 14.2831 0.0222 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 14.1428 0.0220 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 14.1728 0.0223 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 14.0472 0.0218 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 13.8625 0.0220 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 13.8771 0.0220 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 13.7846 0.0219 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 13.6627 0.0219 sec/batch
# Nearest to up: math, fats, kos, newly, bogor, substructure, barricade, zulus,
# Nearest to in: overshadowing, endings, famicom, oj, entrenchment, ugosz, alleles, ongoing,
# Nearest to state: saffron, olympiade, beag, kilocalories, retorted, successor, cladistics, architectural,
# Nearest to most: wrest, hijjah, cielo, kochi, mergers, ropes, planning, cathars,
# Nearest to may: failure, partisanship, interchangeability, hua, shawn, sutton, melton, ngos,
# Nearest to such: mexicans, wlad, latter, eileen, lancer, settle, inexact, naturalisation,
# Nearest to have: uncommon, violinist, externally, keypress, an, fowl, bitches, aleksei,
# Nearest to by: lenat, krebs, agent, ampere, castille, stade, ebooks, demands,
# Nearest to versions: fiennes, emmerdale, plenary, contacted, bios, lithium, acknowledges, yvonne,
# Nearest to brother: toe, snatched, propounded, cartographer, steinbeck, propanone, deum, gables,
# Nearest to taking: lolf, peaceable, boty, coulombs, borwein, malignancy, excitotoxins, shady,
# Nearest to notes: uncompleted, hyperactivity, matriculated, chopin, musashi, reciprocals, performace, kerman,
# Nearest to shows: optic, representationalism, raceway, harpercollins, plots, pwn, puzzling, foundered,
# Nearest to behind: ekaggata, musicianship, staroffice, upholds, mocked, ajmer, livermore, adversary,
# Nearest to proposed: maius, jbls, their, openstep, fiesole, intellects, yum, bc,
# Nearest to arts: qualifying, spitz, easing, homophones, mjs, sagittarius, menteith, synth,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 13.6570 0.0228 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 13.4691 0.0221 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 13.3978 0.0221 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 13.3241 0.0222 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 13.2071 0.0221 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 13.1153 0.0221 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 13.0276 0.0165 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 12.9253 0.0221 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 12.8780 0.0221 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 12.7416 0.0222 sec/batch
# Nearest to up: math, kos, system, fats, zulus, opec, hamburg, gained,
# Nearest to in: the, of, a, overshadowing, gaulois, multiplexer, endings, sqrta,
# Nearest to state: saffron, beag, kilocalories, olympiade, retorted, cladistics, successor, exogenous,
# Nearest to most: wrest, hijjah, mergers, kochi, unaffected, cielo, cathars, yoannis,
# Nearest to may: failure, partisanship, shawn, interchangeability, hua, ngos, melton, overarching,
# Nearest to such: latter, mexicans, eileen, inexact, wlad, salyut, handbook, gpmg,
# Nearest to have: an, uncommon, violinist, bitches, externally, backup, stallone, keypress,
# Nearest to by: castille, ebooks, stade, lenat, fuzz, skinned, had, riverbed,
# Nearest to versions: fiennes, plenary, emmerdale, contacted, bios, yvonne, lithium, bloodedness,
# Nearest to brother: snatched, toe, propounded, deum, cartographer, steinbeck, propanone, gables,
# Nearest to taking: lolf, coulombs, peaceable, boty, excitotoxins, malignancy, intensional, animism,
# Nearest to notes: uncompleted, matriculated, hyperactivity, transcaucasian, chopin, reciprocals, puzzle, performace,
# Nearest to shows: optic, representationalism, raceway, plots, puzzling, xzibit, domination, skeptics,
# Nearest to behind: ekaggata, staroffice, musicianship, upholds, mocked, speaking, darul, livermore,
# Nearest to proposed: maius, openstep, their, jbls, fiesole, intellects, yum, kendrick,
# Nearest to arts: qualifying, homophones, easing, pickguard, synth, spitz, tentatively, lillard,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 12.7177 0.0230 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 12.6790 0.0222 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 12.4746 0.0221 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 12.5248 0.0220 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 12.3613 0.0220 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 12.2873 0.0220 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 12.1213 0.0220 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 12.0443 0.0221 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 12.0165 0.0220 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 12.0617 0.0222 sec/batch
# Nearest to up: math, system, barricade, astride, fats, zulus, opec, bismuth,
# Nearest to in: the, of, and, a, to, is, as, zero,
# Nearest to state: saffron, kilocalories, olympiade, beag, cladistics, retorted, successor, upa,
# Nearest to most: and, the, hijjah, wrest, unaffected, cathars, in, mergers,
# Nearest to may: failure, partisanship, shawn, hua, interchangeability, mundane, calligraphers, melton,
# Nearest to such: of, a, in, the, on, and, one, yunus,
# Nearest to have: an, the, to, of, by, stallone, violinist, and,
# Nearest to by: to, the, of, a, and, in, was, for,
# Nearest to versions: fiennes, acknowledges, yvonne, emmerdale, plenary, bios, contacted, heavy,
# Nearest to brother: propounded, snatched, propanone, steinbeck, toe, deum, cartographer, tremor,
# Nearest to taking: lolf, coulombs, peaceable, boty, lysosomes, malignancy, algorism, intensional,
# Nearest to notes: uncompleted, matriculated, chopin, hyperactivity, transcaucasian, reciprocals, puzzle, chordates,
# Nearest to shows: puzzling, representationalism, chords, raceway, optic, harpercollins, xzibit, tryst,
# Nearest to behind: ekaggata, mocked, musicianship, staroffice, upholds, ajmer, speaking, indications,
# Nearest to proposed: maius, fiesole, openstep, their, jbls, intellects, towering, kendrick,
# Nearest to arts: qualifying, easing, homophones, pickguard, synth, lillard, spitz, menteith,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 12.0493 0.0230 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 11.8174 0.0221 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 11.7027 0.0222 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 11.7183 0.0219 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 11.6866 0.0221 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 11.5961 0.0221 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 11.4545 0.0222 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 11.3958 0.0223 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 11.3647 0.0221 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 11.2969 0.0222 sec/batch
# Nearest to up: system, barricade, zulus, ferry, beaker, astride, and, math,
# Nearest to in: the, of, and, to, was, a, as, for,
# Nearest to state: kilocalories, saffron, beag, olympiade, successor, retorted, cladistics, penh,
# Nearest to most: as, a, an, in, with, which, is, are,
# Nearest to may: failure, shawn, partisanship, hua, mundane, melton, seizes, calligraphers,
# Nearest to such: and, of, a, on, are, with, was, to,
# Nearest to have: are, with, to, or, this, and, for, of,
# Nearest to by: of, to, the, and, in, with, was, is,
# Nearest to versions: emmerdale, acknowledges, fiennes, heavy, lithium, plenary, contacted, bios,
# Nearest to brother: snatched, toe, steinbeck, propounded, propanone, deum, cartographer, neighbourhoods,
# Nearest to taking: peaceable, lolf, coulombs, malignancy, miko, intensional, excitotoxins, algorism,
# Nearest to notes: uncompleted, matriculated, chopin, hyperactivity, transcaucasian, reciprocals, puzzle, performace,
# Nearest to shows: puzzling, chords, representationalism, pwn, tryst, raceway, plots, harpercollins,
# Nearest to behind: mocked, upholds, staroffice, ajmer, musicianship, ekaggata, speaking, providing,
# Nearest to proposed: maius, fiesole, openstep, intellects, towering, nascent, jbls, retains,
# Nearest to arts: qualifying, easing, homophones, synth, pickguard, forrest, lillard, spitz,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 11.3448 0.0231 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 11.1522 0.0221 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 10.9600 0.0225 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 11.0807 0.0226 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 10.9786 0.0227 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 10.9172 0.0225 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 10.8372 0.0224 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 10.8178 0.0218 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 10.6514 0.0221 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 10.5986 0.0219 sec/batch
# Nearest to up: was, s, to, the, at, but, in, which,
# Nearest to in: of, the, and, that, to, is, by, s,
# Nearest to state: kilocalories, albrecht, saffron, individuals, successor, penh, interdisciplinarity, independent,
# Nearest to most: in, and, at, s, the, which, of, was,
# Nearest to may: not, is, an, be, world, also, has, all,
# Nearest to such: the, as, that, to, a, is, be, which,
# Nearest to have: to, it, that, in, is, by, which, and,
# Nearest to by: the, to, of, is, in, and, s, it,
# Nearest to versions: heavy, much, acknowledges, fiennes, emmerdale, contacted, bios, entablature,
# Nearest to brother: snatched, toe, propanone, deum, cartographer, results, steinbeck, propounded,
# Nearest to taking: lolf, peaceable, malignancy, intensional, miko, naval, mathematicians, staying,
# Nearest to notes: uncompleted, chopin, matriculated, transcaucasian, hyperactivity, reciprocals, arid, chordates,
# Nearest to shows: pwn, puzzling, chords, representationalism, xzibit, mccay, plots, optic,
# Nearest to behind: staroffice, ajmer, upholds, mocked, musicianship, many, adversary, ekaggata,
# Nearest to proposed: maius, fiesole, openstep, intellects, towering, jbls, source, pv,
# Nearest to arts: qualifying, easing, homophones, synth, pickguard, forrest, tentatively, spitz,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 10.5933 0.0231 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 10.6683 0.0222 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 10.4648 0.0219 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 10.4646 0.0219 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 10.5071 0.0218 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 10.1948 0.0219 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 10.3918 0.0221 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 10.2277 0.0218 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 10.1308 0.0220 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 10.1238 0.0220 sec/batch
# Nearest to up: being, as, had, that, first, the, s, and,
# Nearest to in: the, and, a, to, as, of, s, were,
# Nearest to state: two, kilocalories, albrecht, penh, by, interdisciplinarity, individuals, th,
# Nearest to most: the, to, for, in, of, a, also, that,
# Nearest to may: into, a, is, to, however, in, as, new,
# Nearest to such: as, a, are, is, that, its, more, an,
# Nearest to have: to, and, are, that, some, as, is, more,
# Nearest to by: of, a, the, and, s, that, with, to,
# Nearest to versions: heavy, bios, acknowledges, consignee, tardive, emmerdale, dark, contacted,
# Nearest to brother: results, up, snatched, cartographer, mooney, toe, propanone, deum,
# Nearest to taking: peaceable, malignancy, contrasts, from, giving, coulombs, lolf, about,
# Nearest to notes: hyperactivity, chopin, uncompleted, transcaucasian, matriculated, reciprocals, performace, chordates,
# Nearest to shows: including, pwn, another, seven, puzzling, four, links, xzibit,
# Nearest to behind: ajmer, speaking, staroffice, quintessential, pedantic, upholds, deaths, ekaggata,
# Nearest to proposed: any, fiesole, maius, openstep, towering, intellects, their, erroneous,
# Nearest to arts: qualifying, homophones, easing, pickguard, synth, tentatively, organization, lillard,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 10.0888 0.0230 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 10.0313 0.0219 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 9.9974 0.0109 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 9.8219 0.0218 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 9.8177 0.0219 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 9.8264 0.0220 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 9.7290 0.0220 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 9.7444 0.0218 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 9.6163 0.0220 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 9.4410 0.0219 sec/batch
# Nearest to up: it, the, that, s, to, would, as, on,
# Nearest to in: of, the, and, by, at, s, with, a,
# Nearest to state: part, five, two, th, national, in, on, eight,
# Nearest to most: that, by, the, but, only, and, at, in,
# Nearest to may: this, it, is, that, all, with, for, a,
# Nearest to such: of, as, is, the, a, be, in, are,
# Nearest to have: and, the, in, that, to, of, is, it,
# Nearest to by: in, of, the, a, only, and, to, but,
# Nearest to versions: heavy, graduated, bios, fiennes, dark, systems, between, much,
# Nearest to brother: toe, results, cartographer, itself, computes, snatched, deum, propanone,
# Nearest to taking: also, contrasts, alms, coulombs, giving, first, naval, with,
# Nearest to notes: hyperactivity, chopin, uncompleted, transcaucasian, matriculated, reciprocals, rilke, definiteness,
# Nearest to shows: of, but, pwn, significant, an, this, the, four,
# Nearest to behind: ajmer, speaking, either, many, it, no, were, encouraged,
# Nearest to proposed: a, fiesole, also, openstep, its, annual, droit, towering,
# Nearest to arts: qualifying, homophones, easing, synth, pickguard, organization, guns, prosperous,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 9.4214 0.0230 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 9.4796 0.0220 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 9.3110 0.0221 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 9.1343 0.0221 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 9.2294 0.0221 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 9.2272 0.0220 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 9.2989 0.0222 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 9.2060 0.0220 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 9.0013 0.0220 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 9.0271 0.0222 sec/batch
# Nearest to up: at, to, a, some, of, have, the, in,
# Nearest to in: with, the, and, of, a, to, as, on,
# Nearest to state: national, states, united, two, government, world, the, five,
# Nearest to most: the, of, as, such, and, some, have, for,
# Nearest to may: that, a, it, or, the, to, any, in,
# Nearest to such: a, some, not, it, are, have, these, most,
# Nearest to have: to, a, of, they, the, it, some, more,
# Nearest to by: the, of, and, with, a, to, in, some,
# Nearest to versions: heavy, bios, systems, dark, online, graduated, contemplate, unrestricted,
# Nearest to brother: won, toe, mid, began, died, cartographer, invented, computes,
# Nearest to taking: a, the, these, also, number, other, to, one,
# Nearest to notes: chopin, hyperactivity, uncompleted, transcaucasian, matriculated, reciprocals, definiteness, one,
# Nearest to shows: modern, it, between, of, about, further, another, five,
# Nearest to behind: either, no, such, further, believed, speaking, a, encouraged,
# Nearest to proposed: while, use, among, of, all, important, source, period,
# Nearest to arts: qualifying, homophones, guns, easing, pickguard, synth, defend, lillard,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 9.0821 0.0227 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 9.0290 0.0219 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 8.7374 0.0219 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 8.7889 0.0218 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 8.9289 0.0222 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 8.6586 0.0219 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 8.7355 0.0219 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 8.8165 0.0219 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 8.4405 0.0219 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 8.6551 0.0218 sec/batch
# Nearest to up: as, the, in, to, not, with, for, that,
# Nearest to in: the, with, and, a, of, to, for, as,
# Nearest to state: part, united, of, the, to, on, political, were,
# Nearest to most: the, a, with, in, for, as, of, and,
# Nearest to may: be, to, are, is, the, many, a, for,
# Nearest to such: is, an, this, can, than, it, or, the,
# Nearest to have: of, as, that, it, to, has, is, the,
# Nearest to by: the, for, a, in, and, with, of, on,
# Nearest to versions: force, systems, using, dark, issue, outside, high, attempt,
# Nearest to brother: died, s, mid, year, won, were, began, giving,
# Nearest to taking: by, like, a, today, when, example, other, has,
# Nearest to notes: hyperactivity, chopin, uncompleted, history, six, transcaucasian, royal, matriculated,
# Nearest to shows: between, work, two, another, further, a, four, off,
# Nearest to behind: either, the, an, then, will, for, always, all,
# Nearest to proposed: since, in, and, any, to, way, further, all,
# Nearest to arts: qualifying, guns, easing, pickguard, homophones, synth, defend, organization,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 8.6862 0.0232 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 8.4264 0.0220 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 8.4875 0.0221 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 8.4862 0.0220 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 8.4139 0.0220 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 8.2794 0.0219 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 8.2431 0.0220 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 8.4599 0.0224 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 8.3092 0.0223 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 8.2565 0.0222 sec/batch
# Nearest to up: to, of, by, a, has, was, an, this,
# Nearest to in: the, of, and, to, was, for, it, a,
# Nearest to state: the, and, of, united, in, political, states, government,
# Nearest to most: the, of, in, to, has, by, from, as,
# Nearest to may: to, are, that, than, with, such, it, more,
# Nearest to such: are, or, other, that, as, these, an, to,
# Nearest to have: not, it, to, is, all, are, that, of,
# Nearest to by: the, of, to, and, for, with, in, as,
# Nearest to versions: version, online, using, it, available, produced, included, primary,
# Nearest to brother: he, began, died, was, first, his, written, year,
# Nearest to taking: this, in, a, position, from, number, out, is,
# Nearest to notes: robert, two, st, general, although, six, nine, short,
# Nearest to shows: for, could, this, the, between, just, where, all,
# Nearest to behind: based, be, no, all, a, only, such, could,
# Nearest to proposed: other, any, of, for, these, that, there, itself,
# Nearest to arts: qualifying, guns, lingua, prosperous, easing, synth, necessity, defend,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 8.4080 0.0229 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 7.9613 0.0219 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 8.2849 0.0218 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 8.1070 0.0220 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 7.9354 0.0220 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 8.0422 0.0217 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 8.0363 0.0218 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 8.0025 0.0220 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 8.0223 0.0052 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 7.8621 0.0219 sec/batch
# Nearest to up: for, a, the, an, to, only, of, from,
# Nearest to in: the, of, for, a, and, to, s, has,
# Nearest to state: states, s, for, the, in, of, united, by,
# Nearest to most: for, to, of, the, not, with, and, a,
# Nearest to may: for, the, is, a, to, all, not, which,
# Nearest to such: as, of, for, is, it, a, that, to,
# Nearest to have: to, a, that, the, for, of, is, be,
# Nearest to by: the, of, in, for, to, s, and, it,
# Nearest to versions: version, available, source, system, commonly, used, number, personal,
# Nearest to brother: died, his, her, returned, was, mother, ii, who,
# Nearest to taking: the, for, a, from, but, by, in, of,
# Nearest to notes: six, two, modern, followed, s, at, history, zero,
# Nearest to shows: the, s, from, a, and, in, been, to,
# Nearest to behind: an, a, on, name, without, because, no, with,
# Nearest to proposed: that, in, a, of, any, is, for, with,
# Nearest to arts: popular, previously, action, keep, film, best, guns, re,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 7.8682 0.0231 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 7.9445 0.0221 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 7.7216 0.0224 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 7.8799 0.0221 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 7.6753 0.0220 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 7.5666 0.0218 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 7.6258 0.0220 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 7.6313 0.0220 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 7.5827 0.0219 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 7.3374 0.0219 sec/batch
# Nearest to up: the, in, to, a, and, for, was, of,
# Nearest to in: the, of, and, to, was, s, at, for,
# Nearest to state: in, the, united, of, under, on, and, states,
# Nearest to most: and, the, in, other, to, by, a, of,
# Nearest to may: be, or, are, a, more, than, different, for,
# Nearest to such: or, a, is, as, than, for, most, often,
# Nearest to have: the, to, by, and, is, of, a, in,
# Nearest to by: the, in, and, of, to, but, most, a,
# Nearest to versions: version, system, source, including, also, into, than, are,
# Nearest to brother: he, her, died, his, was, she, soon, remained,
# Nearest to taking: to, a, for, on, in, and, of, as,
# Nearest to notes: first, note, in, world, home, with, one, until,
# Nearest to shows: often, on, well, including, fact, other, make, been,
# Nearest to behind: to, the, second, of, a, position, at, time,
# Nearest to proposed: the, by, of, a, this, while, first, also,
# Nearest to arts: popular, school, called, previously, she, re, every, former,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 7.4234 0.0229 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 7.3973 0.0218 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 7.5629 0.0218 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 7.5147 0.0219 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 7.2661 0.0218 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 7.3757 0.0218 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 7.4367 0.0216 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 7.4136 0.0217 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 7.1653 0.0219 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 7.2487 0.0221 sec/batch
# Nearest to up: in, the, of, it, when, and, by, to,
# Nearest to in: the, and, of, to, a, by, for, on,
# Nearest to state: states, in, of, by, united, under, government, the,
# Nearest to most: to, in, and, the, of, with, a, which,
# Nearest to may: be, is, to, the, as, this, any, it,
# Nearest to such: it, or, are, is, a, as, can, be,
# Nearest to have: and, to, of, a, the, in, as, more,
# Nearest to by: of, the, and, in, a, to, on, other,
# Nearest to versions: version, on, available, to, use, possible, system, single,
# Nearest to brother: who, died, her, he, his, was, she, former,
# Nearest to taking: of, with, to, a, has, it, any, the,
# Nearest to notes: first, since, was, also, around, of, become, following,
# Nearest to shows: with, as, for, to, a, number, usually, used,
# Nearest to behind: a, on, and, in, with, the, when, of,
# Nearest to proposed: that, to, by, of, provided, for, many, its,
# Nearest to arts: science, school, leader, part, popular, industry, met, historic,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 7.2456 0.0230 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 7.1551 0.0220 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 7.1668 0.0219 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 7.2824 0.0218 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 6.9867 0.0223 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 7.0332 0.0220 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 7.1693 0.0220 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 7.0290 0.0219 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 7.0004 0.0219 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 7.0929 0.0219 sec/batch
# Nearest to up: to, out, which, on, with, into, the, a,
# Nearest to in: the, and, of, at, to, but, on, by,
# Nearest to state: the, united, of, government, states, political, by, in,
# Nearest to most: for, in, on, and, to, a, this, the,
# Nearest to may: to, not, is, only, be, of, the, more,
# Nearest to such: is, this, are, other, it, a, for, be,
# Nearest to have: that, there, many, are, has, to, more, be,
# Nearest to by: of, the, and, to, in, which, with, on,
# Nearest to versions: also, version, information, it, basic, active, on, available,
# Nearest to brother: he, was, had, his, succeeded, died, again, after,
# Nearest to taking: this, on, to, in, when, the, but, and,
# Nearest to notes: which, by, s, first, original, the, see, in,
# Nearest to shows: show, a, fact, this, s, on, special, for,
# Nearest to behind: time, out, on, with, when, has, up, but,
# Nearest to proposed: both, only, all, to, and, are, of, the,
# Nearest to arts: including, school, science, influenced, historic, former, made, best,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 7.0406 0.0226 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 6.7978 0.0220 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 6.8381 0.0217 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 6.9756 0.0217 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 6.9336 0.0220 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 6.8840 0.0217 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 7.1248 0.0219 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 6.6658 0.0218 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 6.9424 0.0219 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 6.9140 0.0219 sec/batch
# Nearest to up: the, a, and, with, at, to, in, an,
# Nearest to in: the, of, and, s, a, with, been, on,
# Nearest to state: states, of, government, in, under, the, united, established,
# Nearest to most: the, as, to, in, a, and, which, have,
# Nearest to may: other, to, it, or, are, have, more, not,
# Nearest to such: some, for, or, but, other, are, it, that,
# Nearest to have: to, the, some, these, which, or, are, many,
# Nearest to by: of, in, to, the, s, for, and, with,
# Nearest to versions: available, source, version, use, features, application, standard, programs,
# Nearest to brother: died, father, king, he, england, his, wife, death,
# Nearest to taking: as, a, however, to, without, but, it, should,
# Nearest to notes: as, at, a, on, and, over, for, the,
# Nearest to shows: a, with, like, for, an, on, both, to,
# Nearest to behind: up, their, while, however, with, on, out, were,
# Nearest to proposed: to, of, the, has, a, not, for, an,
# Nearest to arts: world, science, best, school, home, during, and, s,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 6.7115 0.0230 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 6.7798 0.0220 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 6.7660 0.0219 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 6.7703 0.0220 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 6.8270 0.0219 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 6.6304 0.0213 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 6.6591 0.0219 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 6.8079 0.0219 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 6.6130 0.0220 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 6.7124 0.0218 sec/batch
# Nearest to up: to, as, into, a, all, it, their, the,
# Nearest to in: the, of, and, to, on, s, as, by,
# Nearest to state: states, government, party, war, in, established, international, national,
# Nearest to most: the, to, and, a, much, all, their, however,
# Nearest to may: that, however, to, be, it, or, as, most,
# Nearest to such: more, that, other, be, some, is, than, or,
# Nearest to have: to, or, the, not, because, this, is, all,
# Nearest to by: a, the, of, to, and, in, as, all,
# Nearest to versions: operating, software, version, available, system, user, source, based,
# Nearest to brother: died, his, he, father, king, wife, england, she,
# Nearest to taking: as, most, however, all, to, that, a, the,
# Nearest to notes: and, s, at, the, of, first, an, with,
# Nearest to shows: an, that, on, and, original, both, is, s,
# Nearest to behind: a, as, on, time, s, the, to, their,
# Nearest to proposed: this, but, which, is, an, its, that, and,
# Nearest to arts: world, popular, european, art, home, controversial, its, on,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 6.5880 0.0227 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 6.5127 0.0217 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 6.4928 0.0217 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 6.5602 0.0217 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 6.5320 0.0219 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 6.2779 0.0218 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 6.2660 0.0218 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 6.3828 0.0219 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 6.4546 0.0218 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 6.5462 0.0217 sec/batch
# Nearest to up: on, the, with, in, and, for, at, to,
# Nearest to in: the, of, and, with, s, by, to, on,
# Nearest to state: states, united, national, of, in, the, government, established,
# Nearest to most: the, such, it, a, and, other, with, of,
# Nearest to may: that, it, more, such, are, not, or, any,
# Nearest to such: are, or, use, this, it, which, more, be,
# Nearest to have: of, the, and, to, it, a, been, more,
# Nearest to by: the, in, of, and, to, its, on, both,
# Nearest to versions: based, version, standard, operating, available, system, like, programs,
# Nearest to brother: his, he, her, she, later, wife, father, king,
# Nearest to taking: to, it, have, a, the, for, of, in,
# Nearest to notes: the, of, that, about, and, full, take, note,
# Nearest to shows: with, other, just, it, way, which, this, an,
# Nearest to behind: run, up, the, at, on, around, top, were,
# Nearest to proposed: of, which, the, that, as, an, see, term,
# Nearest to arts: continued, centre, s, national, art, new, world, and,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 6.3199 0.0228 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 6.3885 0.0221 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 6.3925 0.0220 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 6.4585 0.0216 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 6.2863 0.0218 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 6.1340 0.0218 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 6.2848 0.0219 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 6.2500 0.0218 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 6.2276 0.0219 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 6.3289 0.0217 sec/batch
# Nearest to up: on, to, the, it, out, a, in, time,
# Nearest to in: the, and, of, a, as, on, at, from,
# Nearest to state: of, united, states, government, in, the, under, its,
# Nearest to most: the, only, a, and, which, also, in, much,
# Nearest to may: or, be, a, is, are, those, to, that,
# Nearest to such: can, or, are, is, be, these, it, that,
# Nearest to have: to, but, this, that, other, more, not, are,
# Nearest to by: of, on, the, and, in, a, to, for,
# Nearest to versions: standard, version, operating, available, computers, based, programs, users,
# Nearest to brother: died, he, him, his, daughter, her, she, king,
# Nearest to taking: to, a, of, the, for, as, some, but,
# Nearest to notes: about, and, it, at, the, s, which, original,
# Nearest to shows: based, set, example, single, which, a, is, then,
# Nearest to behind: the, when, on, up, in, never, over, made,
# Nearest to proposed: of, as, that, and, in, to, the, towards,
# Nearest to arts: art, s, school, started, education, business, new, first,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 6.1240 0.0227 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 6.0811 0.0216 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 6.2890 0.0218 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 6.1853 0.0226 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 6.1541 0.0225 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 6.2181 0.0226 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 6.2035 0.0224 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 5.9088 0.0226 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 6.0403 0.0216 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 6.0064 0.0218 sec/batch
# Nearest to up: out, on, to, only, the, into, from, when,
# Nearest to in: of, the, to, and, as, by, a, on,
# Nearest to state: states, of, the, government, independent, united, in, under,
# Nearest to most: the, in, and, by, of, many, as, have,
# Nearest to may: to, however, that, be, a, the, certain, not,
# Nearest to such: these, that, a, to, more, it, be, but,
# Nearest to have: that, not, however, but, some, it, to, as,
# Nearest to by: the, of, and, to, in, a, on, as,
# Nearest to versions: version, use, software, computer, operating, feature, tools, features,
# Nearest to brother: his, father, married, died, he, prince, daughter, king,
# Nearest to taking: to, when, a, this, all, however, an, or,
# Nearest to notes: which, written, is, this, references, called, a, note,
# Nearest to shows: show, a, picture, also, you, character, it, this,
# Nearest to behind: a, to, time, down, only, while, this, out,
# Nearest to proposed: a, as, however, only, an, to, and, another,
# Nearest to arts: school, university, education, world, august, met, student, institute,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 6.1419 0.0229 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 6.0656 0.0219 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 6.2428 0.0220 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 6.0871 0.0220 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 5.9503 0.0220 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 6.1541 0.0217 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 5.9549 0.0218 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 5.9301 0.0218 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 5.9164 0.0219 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 6.0356 0.0221 sec/batch
# Nearest to up: an, to, with, being, it, as, the, a,
# Nearest to in: the, of, and, on, s, was, to, has,
# Nearest to state: states, national, government, party, united, federal, under, congress,
# Nearest to most: of, to, in, for, and, the, as, has,
# Nearest to may: more, as, to, some, this, not, that, but,
# Nearest to such: other, as, are, different, often, more, is, create,
# Nearest to have: to, which, of, as, it, the, that, some,
# Nearest to by: of, the, in, on, with, to, for, and,
# Nearest to versions: version, software, operating, user, compatible, computer, tools, system,
# Nearest to brother: father, son, died, wife, prince, charles, henry, daughter,
# Nearest to taking: a, it, to, when, take, the, with, this,
# Nearest to notes: it, which, an, about, for, of, as, the,
# Nearest to shows: show, a, it, time, get, an, and, to,
# Nearest to behind: on, their, the, it, when, time, to, a,
# Nearest to proposed: but, for, of, that, decision, as, on, in,
# Nearest to arts: art, schools, school, started, students, history, and, in,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 6.0225 0.0227 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 5.9082 0.0155 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 5.9144 0.0216 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 6.0222 0.0218 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 5.8909 0.0218 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 5.9195 0.0219 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 5.9420 0.0219 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 5.7497 0.0218 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 5.8790 0.0218 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 5.8197 0.0217 sec/batch
# Nearest to up: to, a, with, the, their, and, in, for,
# Nearest to in: and, the, s, to, of, by, a, their,
# Nearest to state: states, government, under, established, independent, civil, federal, united,
# Nearest to most: as, and, it, other, has, more, is, in,
# Nearest to may: be, is, same, are, these, or, it, some,
# Nearest to such: is, are, often, this, or, can, be, it,
# Nearest to have: as, not, is, to, that, this, it, some,
# Nearest to by: the, and, of, to, in, a, for, from,
# Nearest to versions: version, software, computer, operating, compatible, interface, format, system,
# Nearest to brother: father, king, daughter, son, his, john, married, wife,
# Nearest to taking: a, the, that, on, an, their, with, to,
# Nearest to notes: with, at, and, has, from, an, see, also,
# Nearest to shows: for, with, also, well, it, this, an, has,
# Nearest to behind: the, to, a, and, on, s, time, up,
# Nearest to proposed: which, accepted, as, that, be, maintain, necessary, for,
# Nearest to arts: art, student, college, early, works, school, performing, history,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 5.8550 0.0228 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 5.6972 0.0219 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 5.6216 0.0219 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 5.6508 0.0218 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 5.7996 0.0218 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 5.8620 0.0218 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 5.7251 0.0219 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 5.7168 0.0218 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 5.6675 0.0218 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 5.7799 0.0220 sec/batch
# Nearest to up: a, with, on, the, when, at, for, time,
# Nearest to in: the, a, and, with, of, on, which, to,
# Nearest to state: states, united, established, government, civil, national, affairs, independent,
# Nearest to most: the, which, a, as, although, in, and, it,
# Nearest to may: or, to, a, be, any, are, that, some,
# Nearest to such: is, or, are, a, more, specific, may, can,
# Nearest to have: to, this, other, the, which, or, but, more,
# Nearest to by: the, to, of, for, and, a, in, with,
# Nearest to versions: software, operating, version, compatible, user, programs, computer, system,
# Nearest to brother: john, wife, father, son, she, died, henry, his,
# Nearest to taking: a, the, and, on, in, but, with, while,
# Nearest to notes: and, in, of, the, with, number, to, for,
# Nearest to shows: a, with, and, as, like, for, times, the,
# Nearest to behind: the, back, with, at, out, by, a, on,
# Nearest to proposed: of, that, to, some, which, various, these, by,
# Nearest to arts: art, school, college, student, university, new, continued, founded,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 5.7931 0.0228 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 5.5285 0.0220 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 5.6708 0.0219 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 5.6594 0.0218 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 5.5607 0.0220 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 5.7448 0.0217 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 5.6308 0.0218 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 5.4489 0.0221 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 5.6634 0.0218 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 5.7012 0.0217 sec/batch
# Nearest to up: in, on, going, with, out, to, been, and,
# Nearest to in: the, and, to, a, of, with, as, its,
# Nearest to state: states, of, government, civil, united, national, the, majority,
# Nearest to most: a, not, as, but, in, and, which, it,
# ...
# Nearest to versions: version, operating, windows, pc, interface, software, developers, microsoft,
# Nearest to brother: father, died, his, he, daughter, wife, son, cousin,
# Nearest to taking: to, a, out, time, before, on, danger, would,
# Nearest to notes: note, printed, and, collection, earlier, style, chronological, key,
# Nearest to shows: show, tv, movie, best, appeared, episode, featured, television,
# Nearest to behind: out, hit, went, ever, play, the, next, to,
# Nearest to proposed: general, state, law, observers, independent, obtained, laws, between,
# Nearest to arts: school, college, students, art, martial, university, student, graduate,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 4.6553 0.0237 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 4.6273 0.0225 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 4.6704 0.0225 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 4.6992 0.0219 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 4.7728 0.0219 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 4.7027 0.0219 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 4.7250 0.0223 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 4.6786 0.0221 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 4.7981 0.0218 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 4.7489 0.0221 sec/batch
# Nearest to up: on, with, it, end, when, time, from, which,
# Nearest to in: the, and, from, a, at, as, with, of,
# Nearest to state: states, established, affairs, united, government, independent, department, federal,
# Nearest to most: and, in, with, the, only, from, which, although,
# Nearest to may: or, be, are, individual, not, while, must, can,
# Nearest to such: more, these, other, some, is, are, has, use,
# Nearest to have: more, while, other, or, has, these, some, tend,
# Nearest to by: and, the, of, as, to, in, from, on,
# Nearest to versions: version, windows, operating, pc, microsoft, interface, screen, ms,
# Nearest to brother: died, daughter, son, father, cousin, wife, sons, younger,
# Nearest to taking: out, the, on, but, as, a, at, after,
# Nearest to notes: instrumental, music, reading, printed, introduction, invented, musical, references,
# Nearest to shows: a, on, picture, alternate, show, series, best, with,
# Nearest to behind: back, end, tied, off, passing, down, just, finally,
# Nearest to proposed: theory, theories, basis, general, current, of, existence, expressed,
# Nearest to arts: school, university, academy, art, students, graduate, college, universities,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.5817 0.0229 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.7026 0.0220 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 4.7496 0.0218 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.6858 0.0220 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.7740 0.0219 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.6379 0.0221 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.6277 0.0220 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 4.6917 0.0221 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.6830 0.0222 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.6808 0.0221 sec/batch
# Nearest to up: out, quickly, turn, when, once, back, time, would,
# Nearest to in: the, with, of, and, to, as, from, was,
# Nearest to state: representatives, states, government, constitution, political, established, legislature, national,
# Nearest to most: these, some, and, has, many, in, now, as,
# Nearest to may: to, the, take, not, in, but, be, of,
# Nearest to such: more, it, particular, be, for, or, non, some,
# Nearest to have: some, these, to, as, both, many, been, because,
# Nearest to by: the, of, in, to, and, a, on, with,
# Nearest to versions: version, feature, windows, scripts, unix, developers, microsoft, ms,
# Nearest to brother: daughter, son, eldest, father, his, died, him, heir,
# Nearest to taking: to, out, on, that, this, but, with, the,
# Nearest to notes: reading, introduction, written, references, introductory, edition, norton, handbook,
# Nearest to shows: show, series, featured, original, character, appeared, movie, picture,
# Nearest to behind: out, ever, hit, tied, back, record, throw, turn,
# Nearest to proposed: of, terms, basis, rejected, between, that, establish, debate,
# Nearest to arts: school, university, art, students, student, graduate, institute, faculty,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.6970 0.0230 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.6996 0.0221 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.5537 0.0226 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.6337 0.0219 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.6238 0.0221 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.6261 0.0222 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.7234 0.0223 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.7968 0.0219 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.6978 0.0221 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.5668 0.0221 sec/batch
# Nearest to up: back, out, down, off, once, their, just, never,
# Nearest to in: the, of, and, was, as, on, to, during,
# Nearest to state: states, government, representatives, established, independent, establishment, of, united,
# Nearest to most: are, other, some, the, well, as, and, than,
# Nearest to may: not, to, be, that, it, should, or, the,
# Nearest to such: some, for, these, it, more, that, or, be,
# Nearest to have: as, it, not, many, but, to, an, some,
# Nearest to by: the, of, on, and, with, in, an, as,
# Nearest to versions: version, unix, windows, graphical, feature, microsoft, window, interface,
# Nearest to brother: daughter, son, wife, father, eldest, death, his, died,
# Nearest to taking: would, out, to, take, when, will, an, that,
# Nearest to notes: collection, introduction, reading, written, works, translation, overview, edition,
# Nearest to shows: show, movie, featured, character, series, filmed, fans, movies,
# Nearest to behind: their, out, they, down, while, going, it, up,
# Nearest to proposed: accepted, determination, basis, further, law, attempts, general, argued,
# Nearest to arts: school, students, art, university, martial, student, master, medal,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.7074 0.0226 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.6549 0.0218 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.5326 0.0219 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.5686 0.0220 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.6220 0.0219 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.7000 0.0221 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.6430 0.0148 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.6083 0.0219 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.6409 0.0219 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.6004 0.0222 sec/batch
# Nearest to up: back, before, with, it, when, from, once, down,
# Nearest to in: and, of, the, by, a, s, from, at,
# Nearest to state: states, united, national, government, representatives, established, independent, commission,
# Nearest to most: as, some, among, more, sometimes, their, with, have,
# Nearest to may: be, have, or, an, there, however, not, with,
# Nearest to such: some, other, individual, those, that, because, as, more,
# Nearest to have: not, or, to, that, even, their, be, those,
# Nearest to by: and, in, of, the, a, with, to, for,
# Nearest to versions: version, unix, windows, operating, mac, graphical, interface, os,
# Nearest to brother: wife, died, daughter, son, his, father, married, heir,
# Nearest to taking: to, an, take, a, would, on, when, that,
# Nearest to notes: introduction, musical, music, overview, collection, keys, melody, reading,
# Nearest to shows: show, is, always, sketch, character, describing, picture, drama,
# Nearest to behind: going, move, down, out, up, chance, forward, back,
# Nearest to proposed: further, law, general, determine, establish, basis, fundamental, accepted,
# Nearest to arts: martial, art, students, artists, master, school, style, student,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.5947 0.0232 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.6864 0.0223 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.5361 0.0220 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.5377 0.0220 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.5708 0.0220 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.6400 0.0221 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.5434 0.0221 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.4338 0.0219 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.4952 0.0219 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.5293 0.0227 sec/batch
# Nearest to up: on, end, into, before, from, back, out, when,
# Nearest to in: and, the, from, with, of, as, has, its,
# Nearest to state: states, established, government, independent, representatives, national, administration, legislature,
# Nearest to most: and, other, in, some, more, with, from, well,
# Nearest to may: be, that, because, does, there, it, to, a,
# Nearest to such: some, are, or, as, other, more, can, a,
# Nearest to have: more, because, all, as, to, become, that, they,
# Nearest to by: and, the, for, of, in, s, to, as,
# Nearest to versions: version, windows, unix, mac, graphical, operating, interface, screen,
# Nearest to brother: wife, daughter, father, his, son, uncle, cousin, died,
# Nearest to taking: condition, normal, causing, down, threatening, caused, sudden, a,
# Nearest to notes: note, instruments, music, musical, introduction, melody, harmony, classical,
# Nearest to shows: show, original, drama, picture, movie, appearing, unique, like,
# Nearest to behind: finish, throw, ahead, next, back, down, pass, hit,
# Nearest to proposed: general, establish, terms, of, theoretical, law, further, an,
# Nearest to arts: art, school, student, students, college, affiliated, martial, schools,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 4.5866 0.0235 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.5356 0.0229 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.5641 0.0223 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.5045 0.0219 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.5745 0.0220 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.6409 0.0220 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.4471 0.0217 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.4829 0.0217 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.5567 0.0218 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.4930 0.0217 sec/batch
# Nearest to up: out, back, broken, finally, few, off, time, turn,
# Nearest to in: and, the, a, of, as, for, which, with,
# Nearest to state: general, states, of, affairs, government, national, federal, independent,
# Nearest to most: and, still, also, some, western, which, with, in,
# Nearest to may: can, or, be, are, is, that, a, certain,
# Nearest to such: other, have, often, is, for, can, sometimes, this,
# Nearest to have: are, more, such, these, other, or, than, because,
# Nearest to by: of, a, the, and, to, for, in, its,
# Nearest to versions: version, windows, unix, graphical, pc, operating, feature, linux,
# Nearest to brother: died, son, father, daughter, her, sons, uncle, cousin,
# Nearest to taking: condition, that, a, be, if, then, given, can,
# Nearest to notes: instruments, musical, and, introduction, instrumental, harmony, written, sometimes,
# Nearest to shows: show, looks, series, t, picture, stage, random, so,
# Nearest to behind: down, out, pass, forward, finish, throwing, back, team,
# Nearest to proposed: of, general, state, further, theories, affairs, principles, law,
# Nearest to arts: school, art, student, students, academy, undergraduate, university, graduate,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.5988 0.0227 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.5340 0.0219 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.4230 0.0219 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.5033 0.0217 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.5710 0.0217 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.5015 0.0219 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.5043 0.0217 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.5114 0.0217 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.4470 0.0219 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.4339 0.0219 sec/batch
# Nearest to up: out, once, when, to, on, with, off, quickly,
# Nearest to in: the, of, and, by, to, as, its, from,
# Nearest to state: states, of, established, government, the, independent, political, in,
# Nearest to most: and, other, as, in, of, are, some, has,
# Nearest to may: be, however, not, does, is, to, or, that,
# Nearest to such: to, for, is, some, not, be, more, which,
# Nearest to have: more, not, that, as, an, however, has, it,
# Nearest to by: of, the, and, in, on, its, which, over,
# Nearest to versions: version, feature, graphical, unix, windows, microsoft, ported, graphic,
# Nearest to brother: daughter, his, father, died, cousin, heir, son, throne,
# Nearest to taking: given, this, that, then, always, when, out, itself,
# Nearest to notes: melody, note, sound, tone, sounding, tones, instruments, harmonic,
# Nearest to shows: show, picture, series, drama, movie, comedy, scenes, best,
# Nearest to behind: out, down, will, going, move, off, keep, standing,
# Nearest to proposed: of, laws, an, law, general, the, further, accepted,
# Nearest to arts: students, school, student, art, faculty, university, college, graduate,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.4807 0.0226 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.4731 0.0219 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.5459 0.0218 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.6076 0.0217 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.6693 0.0216 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.4217 0.0218 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.5083 0.0217 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.5012 0.0216 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.3643 0.0218 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.4600 0.0217 sec/batch
# Nearest to up: very, to, on, with, their, a, being, take,
# Nearest to in: the, and, s, on, to, other, of, several,
# Nearest to state: states, national, congress, established, former, united, legislature, central,
# Nearest to most: more, has, other, some, as, well, and, these,
# Nearest to may: be, this, is, or, there, for, a, depending,
# Nearest to such: as, for, some, these, be, more, that, or,
# Nearest to have: some, more, to, many, other, their, as, these,
# Nearest to by: of, the, and, with, in, to, a, other,
# Nearest to versions: version, unix, ported, features, os, windows, feature, microsoft,
# Nearest to brother: father, daughter, son, his, wife, cousin, daughters, died,
# Nearest to taking: this, to, a, is, that, because, if, given,
# Nearest to notes: harmony, works, classical, reference, music, melody, comprehensive, instrumental,
# Nearest to shows: show, best, featured, drama, movie, series, videos, appeared,
# Nearest to behind: out, you, ever, back, down, going, my, go,
# Nearest to proposed: basis, general, accepted, measures, mass, further, independent, commission,
# Nearest to arts: students, art, student, martial, school, schools, curriculum, academic,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.4733 0.0229 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.5017 0.0219 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
